# %%
import pandas as pd
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..', 'scripts')))
# Load the text file into a pandas DataFrame
file_path = '../data/MachineLearningRating_v3.txt'  # Update with your file's path
data = pd.read_csv(file_path, sep='|')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15020\611414113.py:7: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path, sep='|')

# %%
from preprocess import preprocess
preprocess(data)
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000098 entries, 0 to 1000097
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   UnderwrittenCoverID       1000098 non-null  int64
#  1   PolicyID                  1000098 non-null  int64
#  2   TransactionMonth          1000098 non-null  object
#  3   IsVATRegistered           1000098 non-null  bool
#  4   Citizenship               1000098 non-null  object
#  5   LegalType                 1000098 non-null  object
#  6   Title                     1000098 non-null  object
#  7   Language                  1000098 non-null  object
#  8   Bank                      959866 non-null   object
#  9   AccountType               959866 non-null   object
#  10  MaritalStatus             1000098 non-null  object
#  11  Gender                    1000098 non-null  object
#  12  Country                   1000098 non-null  object
#  13  Province                  1000098 non-null  object
#  14  PostalCode                1000098 non-null  int64
#  15  MainCrestaZone            1000098 non-null  object
#  16  SubCrestaZone             1000098 non-null  object
#  17  ItemType                  1000098 non-null  object
#  18  mmcode                    999546 non-null   float64
#  19  VehicleType               999546 non-null   object
#  20  RegistrationYear          1000098 non-null  int64
#  21  make                      999546 non-null   object
#  22  Model                     999546 non-null   object
#  23  Cylinders                 999546 non-null   float64
#  24  cubiccapacity             999546 non-null   float64
#  25  kilowatts                 999546 non-null   float64
#  26  bodytype                  999546 non-null   object
#  27  NumberOfDoors             999546 non-null   float64
#  28  VehicleIntroDate          999546 non-null   object
#  29  CustomValueEstimate       220456 non-null   float64
#  30  AlarmImmobiliser          1000098 non-null  object
#  31  TrackingDevice            1000098 non-null  object
#  32  CapitalOutstanding        1000096 non-null  object
#  33  NewVehicle                846803 non-null   object
#  34  WrittenOff                358197 non-null   object
#  35  Rebuilt                   358197 non-null   object
#  36  Converted                 358197 non-null   object
#  37  CrossBorder               698 non-null      object
#  38  NumberOfVehiclesInFleet   0 non-null        float64
#  39  SumInsured                1000098 non-null  float64
#  40  TermFrequency             1000098 non-null  object
#  41  CalculatedPremiumPerTerm  1000098 non-null  float64
#  42  ExcessSelected            1000098 non-null  object
#  43  CoverCategory             1000098 non-null  object
#  44  CoverType                 1000098 non-null  object
#  45  CoverGroup                1000098 non-null  object
#  46  Section                   1000098 non-null  object
#  47  Product                   1000098 non-null  object
#  48  StatutoryClass            1000098 non-null  object
#  49  StatutoryRiskType         1000098 non-null  object
#  50  TotalPremium              1000098 non-null  float64
#  51  TotalClaims               1000098 non-null  float64
# dtypes: bool(1), float64(11), int64(4), object(36)
# memory usage: 390.1+ MB
# None
#
# First 5 Rows:
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# 3              Close Corporation    Mr  English  First National Bank
# 4              Close Corporation    Mr  English  First National Bank
#
#        AccountType  ...                    ExcessSelected CoverCategory  \
# 0  Current account  ...             Mobility - Windscreen    Windscreen
# 1  Current account  ...             Mobility - Windscreen    Windscreen
# 2  Current account  ...             Mobility - Windscreen    Windscreen
# 3  Current account  ...  Mobility - Metered Taxis - R2000    Own damage
# 4  Current account  ...  Mobility - Metered Taxis - R2000    Own damage
#
#     CoverType            CoverGroup              Section  \
# 0  Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 1  Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 2  Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 3  Own Damage  Comprehensive - Taxi  Motor Comprehensive
# 4  Own Damage  Comprehensive - Taxi  Motor Comprehensive
#
#                            Product StatutoryClass StatutoryRiskType  \
# 0  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 1  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 2  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 3  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 4  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
#
#    TotalPremium TotalClaims
# 0     21.929825         0.0
# 1     21.929825         0.0
# 2      0.000000         0.0
# 3    512.848070         0.0
# 4      0.000000         0.0
#
# [5 rows x 52 columns]
#        TotalPremium   TotalClaims
# count  1.000098e+06  1.000098e+06
# mean   6.190550e+01  6.486119e+01
# std    2.302845e+02  2.384075e+03
# min   -7.825768e+02 -1.200241e+04
# 25%    0.000000e+00  0.000000e+00
# 50%    2.178333e+00  0.000000e+00
# 75%    2.192982e+01  0.000000e+00
# max    6.528260e+04  3.930921e+05
#
# Data Types of Columns:
# UnderwrittenCoverID           int64
# PolicyID                      int64
# TransactionMonth             object
# IsVATRegistered                bool
# Citizenship                  object
# LegalType                    object
# Title                        object
# Language                     object
# Bank                         object
# AccountType                  object
# MaritalStatus                object
# Gender                       object
# Country                      object
# Province                     object
# PostalCode                    int64
# MainCrestaZone               object
# SubCrestaZone                object
# ItemType                     object
# mmcode                      float64
# VehicleType                  object
# RegistrationYear              int64
# make                         object
# Model                        object
# Cylinders                   float64
# cubiccapacity               float64
# kilowatts                   float64
# bodytype                     object
# NumberOfDoors               float64
# VehicleIntroDate             object
# CustomValueEstimate         float64
# AlarmImmobiliser             object
# TrackingDevice               object
# CapitalOutstanding           object
# NewVehicle                   object
# WrittenOff                   object
# Rebuilt                      object
# Converted                    object
# CrossBorder                  object
# NumberOfVehiclesInFleet     float64
# SumInsured                  float64
# TermFrequency                object
# CalculatedPremiumPerTerm    float64
# ExcessSelected               object
# CoverCategory                object
# CoverType                    object
# CoverGroup                   object
# Section                      object
# Product                      object
# StatutoryClass               object
# StatutoryRiskType            object
# TotalPremium                float64
# TotalClaims                 float64
# dtype: object
#
# Missing Values in Each Column:
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                       0
# LegalType                         0
# Title                             0
# Language                          0
# Bank                          40232
# AccountType                   40232
# MaritalStatus                     0
# Gender                            0
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                          552
# VehicleType                     552
# RegistrationYear                  0
# make                            552
# Model                           552
# Cylinders                       552
# cubiccapacity                   552
# kilowatts                       552
# bodytype                        552
# NumberOfDoors                   552
# VehicleIntroDate                552
# CustomValueEstimate          779642
# AlarmImmobiliser                  0
# TrackingDevice                    0
# CapitalOutstanding                2
# NewVehicle                   153295
# WrittenOff                   641901
# Rebuilt                      641901
# Converted                    641901
# CrossBorder                  999400
# NumberOfVehiclesInFleet     1000098
# SumInsured                        0
# TermFrequency                     0
# CalculatedPremiumPerTerm          0
# ExcessSelected                    0
# CoverCategory                     0
# CoverType                         0
# CoverGroup                        0
# Section                           0
# Product                           0
# StatutoryClass                    0
# StatutoryRiskType                 0
# TotalPremium                      0
# TotalClaims                       0
# dtype: int64

# %%
from data_analysis import univariate_analysis,bivariate_analysis
univariate_analysis(data)
bivariate_analysis(data)
# Out:
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:58: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_categories.index, y=top_categories.values, palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:76: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:76: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:76: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:76: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:58: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_categories.index, y=top_categories.values, palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:76: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:76: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:76: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:76: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:76: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:58: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_categories.index, y=top_categories.values, palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:81: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:58: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_categories.index, y=top_categories.values, palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:81: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:76: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:81: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:76: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:81: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:58: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_categories.index, y=top_categories.values, palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:81: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:58: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_categories.index, y=top_categories.values, palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:81: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:58: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_categories.index, y=top_categories.values, palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:81: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:58: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_categories.index, y=top_categories.values, palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:81: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:76: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:81: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:76: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:81: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:76: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:81: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:76: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:81: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:76: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:81: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:76: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:81: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:76: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:81: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:58: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_categories.index, y=top_categories.values, palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:81: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:58: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_categories.index, y=top_categories.values, palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:81: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:58: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_categories.index, y=top_categories.values, palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:81: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:76: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:81: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:76: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:81: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:76: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:81: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:76: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data[col], palette="Set2")
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\data_analysis.py:81: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
# Descriptive Statistics for Monthly Changes:
#        Change_TotalPremium  Change_TotalClaims
# count        999210.000000       999210.000000
# mean              0.062487           -0.007297
# std             319.322843         3371.801578
# min          -65282.603421      -393092.105263
# 25%              -4.807018            0.000000
# 50%               0.000000            0.000000
# 75%               5.168224            0.000000
# max           65282.603421       393092.105263
#
# Correlation Matrix:
#                      Change_TotalPremium  Change_TotalClaims
# Change_TotalPremium             1.000000            0.121041
# Change_TotalClaims              0.121041            1.000000

# %%
from trends_by_geo import trends
trends(data)
# Out:
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\trends_by_geo.py:36: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\trends_by_geo.py:93: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
from outliers import outliers
outliers(data)
# Out:
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\outliers.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, y=column, palette='Set2')
# Number of outliers detected in TotalPremium: 209042
#         UnderwrittenCoverID  PolicyID TransactionMonth  IsVATRegistered  \
# 624006                 1210       159       2013-11-01            False
# 636397                 1220       159       2013-11-01            False
# 636421                 1211       159       2013-11-01            False
# 666094                 1224       159       2013-11-01            False
# 791234                 1212       159       2013-11-01            False
# ...                     ...       ...              ...              ...
# 237620               108902      8075       2015-08-01            False
# 255728               108916      8075       2015-08-01            False
# 261474               108901      8075       2015-08-01            False
# 290453               108905      8075       2015-08-01            False
# 290463               108908      8075       2015-08-01            False
#
#        Citizenship   LegalType Title Language                 Bank  \
# 624006              Individual    Mr  English        Standard Bank
# 636397              Individual    Mr  English        Standard Bank
# 636421              Individual    Mr  English        Standard Bank
# 666094              Individual    Mr  English        Standard Bank
# 791234              Individual    Mr  English        Standard Bank
# ...            ...         ...   ...      ...                  ...
# 237620              Individual    Mr  English  First National Bank
# 255728              Individual    Mr  English  First National Bank
# 261474              Individual    Mr  English  First National Bank
# 290453              Individual    Mr  English  First National Bank
# 290463              Individual    Mr  English  First National Bank
#
#             AccountType  ...            CoverGroup                   Section  \
# 624006  Current account  ...      Income Protector  Optional Extended Covers
# 636397  Current account  ...  Comprehensive - Taxi       Motor Comprehensive
# 636421  Current account  ...      Income Protector  Optional Extended Covers
# 666094  Current account  ...  Comprehensive - Taxi       Motor Comprehensive
# 791234  Current account  ...      Income Protector  Optional Extended Covers
# ...                 ...  ...                   ...                       ...
# 237620  Current account  ...  Comprehensive - Taxi       Motor Comprehensive
# 255728  Current account  ...  Comprehensive - Taxi       Motor Comprehensive
# 261474  Current account  ...  Comprehensive - Taxi       Motor Comprehensive
# 290453  Current account  ...      Income Protector  Optional Extended Covers
# 290463  Current account  ...   Basic Excess Waiver  Optional Extended Covers
#
#                                    Product StatutoryClass  StatutoryRiskType  \
# 624006     Mobility Metered Taxis: Monthly     Commercial      IFRS Constant
# 636397     Mobility Metered Taxis: Monthly     Commercial      IFRS Constant
# 636421     Mobility Metered Taxis: Monthly     Commercial      IFRS Constant
# 666094     Mobility Metered Taxis: Monthly     Commercial      IFRS Constant
# 791234     Mobility Metered Taxis: Monthly     Commercial      IFRS Constant
# ...                                    ...            ...                ...
# 237620  Mobility Commercial Cover: Monthly     Commercial      IFRS Constant
# 255728  Mobility Commercial Cover: Monthly     Commercial      IFRS Constant
# 261474  Mobility Commercial Cover: Monthly     Commercial      IFRS Constant
# 290453  Mobility Commercial Cover: Monthly     Commercial      IFRS Constant
# 290463  Mobility Commercial Cover: Monthly     Commercial      IFRS Constant
#
#        TotalPremium   TotalClaims Change_TotalPremium  Change_TotalClaims  \
# 624006    59.649123      0.000000           57.808982            0.000000
# 636397   345.305614  44444.728070          345.305614        44444.728070
# 636421    59.649123      0.000000           42.105263            0.000000
# 666094   324.470105      0.000000          321.876421            0.000000
# 791234    59.649123   6140.350877           57.920000         6140.350877
# ...             ...           ...                 ...                 ...
# 237620   208.995351      0.000000         -239.880877            0.000000
# 255728   448.876228      0.000000          444.696316            0.000000
# 261474   208.995351      0.000000          165.135702            0.000000
# 290453    74.561404      0.000000           70.381491            0.000000
# 290463    78.947368      0.000000            4.385965            0.000000
#
#        YearMonth
# 624006   2013-11
# 636397   2013-11
# 636421   2013-11
# 666094   2013-11
# 791234   2013-11
# ...          ...
# 237620   2015-08
# 255728   2015-08
# 261474   2015-08
# 290453   2015-08
# 290463   2015-08
#
# [209042 rows x 55 columns]
# Column TotalClaim not found in the dataset. Skipping.

# %%
from visualization import visualization
visualization(data)
# Out:
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\visualization.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# c:\Users\HP\Desktop\week-3\kaim-week-3\scripts\visualization.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
